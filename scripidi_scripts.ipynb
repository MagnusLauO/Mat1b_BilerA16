# %% [markdown]
# yayayayayay

# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ... $F(t)]$
# ![image-3.png](attachment:image-3.png)
